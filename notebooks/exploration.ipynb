# %% [markdown]
# # Pricing Intelligence Exploration
# This notebook is a quick sandbox for inspecting raw data, engineered features, and baseline return behavior.

# %%
import pandas as pd
from src.data_ingestion import fetch_market_data
from src.feature_engineering import engineer_features

# %%
raw = fetch_market_data('AAPL', '2020-01-01', '2025-01-01')
features = engineer_features(raw)
raw.tail(), features.tail()
